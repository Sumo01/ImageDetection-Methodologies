# %% [markdown]
# # Canny Edge Detection

# %% [markdown]
# Canny edge detection is a popular edge detection algorithm developed by John F. Canny in 1986. It is widely used in image processing and computer vision to identify and extract the edges of objects in an image.

# %% [markdown]
# The Canny edge detection algorithm consists of multiple steps:
#
# 1. **Noise Reduction:** The first step is typically to reduce noise in the image to avoid detecting false edges. This is commonly done using a Gaussian filter, which smooths the image by convolving it with a Gaussian kernel. The filter removes high-frequency noise while preserving the edges.
#
# 2. **Gradient Calculation:** The next step involves calculating the gradient magnitude and direction for each pixel in the image. The gradient provides information about the intensity variations in the image and helps identify potential edge locations. This is usually achieved by applying derivative operators, such as the Sobel operator, in the horizontal and vertical directions.
#
# 3. **Non-maximum Suppression:** In this step, the algorithm performs non-maximum suppression to thin out the detected edges. It examines the gradient magnitude and direction to suppress all non-maximum values along the direction of the gradient. This process helps to produce thin, continuous edges.
#
# 4. **Double Thresholding:** Canny edge detection uses double thresholding to determine which edges to keep and which ones to discard. The algorithm applies two thresholds: a high threshold and a low threshold. If the gradient magnitude is above the high threshold, it is considered a strong edge pixel. If the gradient magnitude is below the low threshold, it is considered a weak edge pixel. Values between the high and low thresholds are considered potential edges.
#
# 5. **Edge Tracking by Hysteresis:** Weak edges that are connected to strong edges are retained as part of the final edge map. This is achieved through a process called edge tracking by hysteresis. Starting from the strong edge pixels, the algorithm follows the weak edges as long as they are connected to strong edges. This ensures the continuity of edges and suppresses isolated weak edges.

# %% [markdown]
# The result of the Canny edge detection algorithm is a binary image where the edges are represented as white pixels, while the non-edge regions are black. The algorithm is effective in detecting a wide range of edges, including those with low contrast or noise, and it provides precise and well-connected edges.

# %% [markdown]
# ## Code

# %% [markdown]
# Code Source: https://docs.opencv.org/3.4/da/d22/tutorial_py_canny.html

# %%
# !pip install opencv-python-headless
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 30.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('Images/lena.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"

plt.figure(figsize=(20, 40))
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
edges = cv.Canny(img,300,200)
plt.figure(figsize=(20, 40))
plt.subplot(122)
plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
